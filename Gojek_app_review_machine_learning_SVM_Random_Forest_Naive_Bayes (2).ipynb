# %% [markdown]
# <a href="https://colab.research.google.com/github/aliyaaliyal/mesin-learning/blob/main/Gojek_app_review_machine_learning_SVM_Random_Forest_Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
#from google_play_scraper import app

import pandas as pd

import numpy as np

# %% [markdown]
# # Scrapping 10000 data review gojek

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.lemon.lvoverseas',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=10000, # defaults to 100
    filter_score_with=None
)

# %%
print(result[0])
# Out:
# {'reviewId': '90d563f7-67fa-4b74-af41-ef901709dcee', 'userName': 'Pengguna Google', 'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g', 'content': 'jadi males kadang kalau mau ngedit lagi , soalnya semua berbayar ,dulu efek , filter, banyak yang bisa digunakan,sekarang kudu berlangganan dulu , padahal kalau makai gak sebulan full (bisa dihitung jari lah) , setiap update pasti berbayar semua, kembalikan versi kayak yang dulu please !!! kalau dibilang suka sama aplikasi ini sih suka ,karena fiturnya hampir lengkap, kalau buat ngedit yang biasa biasa ,tapi kenapa makin kesini makin berbayar semua 😭 moga di perbaiki lagi ya 🥲', 'score': 2, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2025, 6, 6, 13, 12, 27), 'replyContent': None, 'repliedAt': None, 'appVersion': None}

# %%
data = pd.DataFrame(np.array(result), columns=['review'])

data = data.join(pd.DataFrame(data.pop('review').tolist()))

data
# Out:
#                                   reviewId         userName  \
# 0     90d563f7-67fa-4b74-af41-ef901709dcee  Pengguna Google
# 1     fdfb2409-40ee-4ba8-ad1d-4033cf6447ec  Pengguna Google
# 2     ba8648a1-df17-4b48-904d-19f14075a1b4  Pengguna Google
# 3     2f1d5625-d3f4-4a12-9a83-aec45566924a  Pengguna Google
# 4     27807408-4cbe-4df3-84e4-f20ff6372477  Pengguna Google
# ...                                    ...              ...
# 9995  0e3ed92b-4ff3-416e-9b12-60e7b0d20b9b   Cindy syakilla
# 9996  d37f2592-e0e7-48c3-945f-355262051074      Ini Chanell
# 9997  fad04bab-020b-402e-93bc-1741fbd26ed6     Tauzia Syifa
# 9998  31ef948e-4fbd-4d36-9d90-5f33e590c209     Musik Player
# 9999  7417265f-32e3-4d6f-8968-17327b1eb4cb          ZUMZUMI
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 9995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 0     jadi males kadang kalau mau ngedit lagi , soal...      2              0
# 1     Kecewa berat sih sama ni aplikasi. Dulu sih iy...      1            415
# 2     capcut makin ke sini makin "berkembang" ya—fit...      1             87
# 3     ini apliaksi ap sih?, semua harus bayar, oke k...      1             46
# 4     keluh kesah saya,kenapa capcut saya selalu bug...      5            201
# ...                                                 ...    ...            ...
# 9995        iklan terus,kebanyakan pro ky mau naik haji      1              0
# 9996  Semenjak diupdate iklannya ga ngotak ,1 video ...      1              0
# 9997                       capcut banyak iklan sekarang      3              0
# 9998  iklan di mana mana,mau masuk iklan,mau eksport...      1              0
# 9999  terimakasih sudah memudahkan kami untuk berkreasi      5              0
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                    None 2025-06-06 13:12:27         None       NaT
# 1                  14.5.0 2025-06-21 13:03:19         None       NaT
# 2                  14.5.0 2025-06-22 03:19:54         None       NaT
# 3                  14.5.0 2025-06-26 01:06:21         None       NaT
# 4                  14.6.0 2025-06-26 11:54:50         None       NaT
# ...                   ...                 ...          ...       ...
# 9995               14.4.0 2025-06-07 07:36:31         None       NaT
# 9996               13.7.0 2025-02-28 13:27:00         None       NaT
# 9997               14.4.0 2025-06-10 05:10:06         None       NaT
# 9998               13.6.0 2025-01-09 22:18:57         None       NaT
# 9999               14.4.0 2025-06-09 14:45:36         None       NaT
#
#      appVersion
# 0          None
# 1        14.5.0
# 2        14.5.0
# 3        14.5.0
# 4        14.6.0
# ...         ...
# 9995     14.4.0
# 9996     13.7.0
# 9997     14.4.0
# 9998     13.6.0
# 9999     14.4.0
#
# [10000 rows x 11 columns]

# %%
scrappeddata1 = data[['content','score','at']]
sorteddata = scrappeddata1.sort_values(by='at', ascending=True) #Sort by Newest, change to True if you want to sort by Oldest.
sorteddata.head()
# Out:
#                                                 content  score  \
# 9733  Aplikasinya bagus, aku suka Tapi ada kekuranga...      4
# 8862  Aplikasinya bagus. Fiturnya lengkap dan bisa o...      5
# 8629  Semua udah bagus.. Hanya saja sedikit saran.. ...      4
# 8029  Aplikasi sudah bagus secara keseluruhan. Cuma ...      4
# 7891  Mau ngasih tau aja,kenapa ya apk capcut kalo b...      3
#
#                       at
# 9733 2021-01-14 15:08:31
# 8862 2021-03-25 14:13:02
# 8629 2021-05-23 08:58:26
# 8029 2021-09-04 13:46:45
# 7891 2021-10-08 10:21:59

# %%
sorteddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 9733 to 7520
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  10000 non-null  object
#  1   score    10000 non-null  int64
#  2   at       10000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 312.5+ KB

# %%
sorteddata['Year'] = sorteddata['at'].dt.year
sorteddata['Month'] = sorteddata['at'].dt.month
sorteddata['Day'] = sorteddata['at'].dt.day

# %%
sorteddata
# Out:
#                                                 content  score  \
# 9733  Aplikasinya bagus, aku suka Tapi ada kekuranga...      4
# 8862  Aplikasinya bagus. Fiturnya lengkap dan bisa o...      5
# 8629  Semua udah bagus.. Hanya saja sedikit saran.. ...      4
# 8029  Aplikasi sudah bagus secara keseluruhan. Cuma ...      4
# 7891  Mau ngasih tau aja,kenapa ya apk capcut kalo b...      3
# ...                                                 ...    ...
# 2292  Halah taik naa sekarang semua fitur jadi premi...      1
# 2914  kenapa semua fitur-fitur nya prabayar. semakin...      5
# 5586  aplikasi kont tidak berguna semua fitur harus ...      1
# 2909  apalah capcut nih, internet masih banyak jarin...      1
# 7520  Sebenarnya Ini Bagus Apk Yang Paling Bagus Bua...      5
#
#                       at  Year  Month  Day
# 9733 2021-01-14 15:08:31  2021      1   14
# 8862 2021-03-25 14:13:02  2021      3   25
# 8629 2021-05-23 08:58:26  2021      5   23
# 8029 2021-09-04 13:46:45  2021      9    4
# 7891 2021-10-08 10:21:59  2021     10    8
# ...                  ...   ...    ...  ...
# 2292 2025-06-27 16:05:01  2025      6   27
# 2914 2025-06-27 16:56:29  2025      6   27
# 5586 2025-06-27 16:57:48  2025      6   27
# 2909 2025-06-27 17:00:02  2025      6   27
# 7520 2025-06-27 17:21:57  2025      6   27
#
# [10000 rows x 6 columns]

# %%
df = sorteddata[['content','score','Year','Month','Day']]
df
# Out:
#                                                 content  score  Year  Month  \
# 9733  Aplikasinya bagus, aku suka Tapi ada kekuranga...      4  2021      1
# 8862  Aplikasinya bagus. Fiturnya lengkap dan bisa o...      5  2021      3
# 8629  Semua udah bagus.. Hanya saja sedikit saran.. ...      4  2021      5
# 8029  Aplikasi sudah bagus secara keseluruhan. Cuma ...      4  2021      9
# 7891  Mau ngasih tau aja,kenapa ya apk capcut kalo b...      3  2021     10
# ...                                                 ...    ...   ...    ...
# 2292  Halah taik naa sekarang semua fitur jadi premi...      1  2025      6
# 2914  kenapa semua fitur-fitur nya prabayar. semakin...      5  2025      6
# 5586  aplikasi kont tidak berguna semua fitur harus ...      1  2025      6
# 2909  apalah capcut nih, internet masih banyak jarin...      1  2025      6
# 7520  Sebenarnya Ini Bagus Apk Yang Paling Bagus Bua...      5  2025      6
#
#       Day
# 9733   14
# 8862   25
# 8629   23
# 8029    4
# 7891    8
# ...   ...
# 2292   27
# 2914   27
# 5586   27
# 2909   27
# 7520   27
#
# [10000 rows x 5 columns]

# %%
df['score'].value_counts()
# Out:
# score
# 1    5185
# 5    1402
# 2    1401
# 3    1196
# 4     816
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 9733 to 7520
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  10000 non-null  object
#  1   score    10000 non-null  int64
#  2   Year     10000 non-null  int32
#  3   Month    10000 non-null  int32
#  4   Day      10000 non-null  int32
# dtypes: int32(3), int64(1), object(1)
# memory usage: 351.6+ KB

# %% [markdown]
# # Jumlah Review berdasarkan score/rating

# %%
df.groupby(['score']).size().plot(kind = "bar")
# Out:
# <Axes: xlabel='score'>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Distribusi Score/Rating

# %%
# use the groupby() function to group island column
# and apply size() function
# size() is equivalent to counting the distinct rows
import seaborn as sns
result = df.groupby(['score']).size()

# plot the result
sns.barplot(x = result.index, y = result.values)
# Out:
# <Axes: xlabel='score'>

# %% [markdown]
# # Kolom Sentimen
# Menambahkan kolom sentimen dengan kriteria, score 1-2 --> negatif dengan kode -1, score 3 adalah netral dengan kode angka 0 dan score 4-5 adalah positif dengan kode 1

# %%
sentimen = []
for index, row in df.iterrows():
    if row['score'] > 3 :
        sentimen.append(1)
    elif row['score'] == 3:
        sentimen.append(0)
    else:
        sentimen.append(-1)
df['sentiment'] = sentimen
df.head()
# Out:
#                                                 content  score  Year  Month  \
# 9733  Aplikasinya bagus, aku suka Tapi ada kekuranga...      4  2021      1
# 8862  Aplikasinya bagus. Fiturnya lengkap dan bisa o...      5  2021      3
# 8629  Semua udah bagus.. Hanya saja sedikit saran.. ...      4  2021      5
# 8029  Aplikasi sudah bagus secara keseluruhan. Cuma ...      4  2021      9
# 7891  Mau ngasih tau aja,kenapa ya apk capcut kalo b...      3  2021     10
#
#       Day  sentiment
# 9733   14          1
# 8862   25          1
# 8629   23          1
# 8029    4          1
# 7891    8          0

# %% [markdown]
# ## Distribusi Sentimen

# %%
df_new = df[['Year', 'Month', 'sentiment']]
#df_new
result = df_new.groupby(['sentiment']).size()

# plot the result
sns.barplot(x = result.index, y = result.values)
# Out:
# <Axes: xlabel='sentiment'>

# %%
#plot a bar graph to show count of tweet sentiment
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(7,5))
color = ['green','grey','red']
df_new['sentiment'].value_counts().plot(kind='bar',color = color)
plt.title('Jumlah Review tiap Sentiment')
plt.ylabel('Jumlah')
plt.xlabel('Sentimen')
plt.grid(False)
plt.show()

# %%
#pie chart to show percentage distribution of polarity
fig = plt.figure(figsize=(7,7))
colors = ('red', 'grey', 'green')
wp={'linewidth':2, 'edgecolor': 'black'}
tags=df_new['sentiment'].value_counts()
explode = (0.1,0.1,0.1)
tags.plot(kind='pie', autopct='%1.1f%%', shadow=True, colors=colors,
         startangle=90, wedgeprops=wp, explode=explode, label='')
plt.title('Distribution of sentiment')
# Out:
# Text(0.5, 1.0, 'Distribution of sentiment')

# %% [markdown]
# ## Distribusi Sentimen per tahun

# %%
import seaborn as sns
sns.countplot(data=df_new,x='Year',hue='sentiment')
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
df2 = df_new.groupby(['Year'])['Month'].count()
df2
# Out:
# Year
# 2021       5
# 2022       3
# 2023       3
# 2024      27
# 2025    9962
# Name: Month, dtype: int64

# %%
df3 = df_new.groupby(['Year','sentiment'])['sentiment'].count()
df3
# Out:
# Year  sentiment
# 2021   0              1
#        1              4
# 2022  -1              1
#        1              2
# 2023  -1              1
#        1              2
# 2024  -1             18
#        0              6
#        1              3
# 2025  -1           6566
#        0           1189
#        1           2207
# Name: sentiment, dtype: int64

# %%
import pandas as pd
import string
import nltk

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# -1    6586
#  1    2218
#  0    1196
# Name: count, dtype: int64

# %% [markdown]
# # Tahapan Preprocessing

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# **Menghapus URL dari kolom konten**

# %%
df['content'] = df['content'].str.replace('https\S+', ' ', case=False)

# %% [markdown]
# **Merubah Teks Jadi Lower Case**

# %%
df['content'] = df['content'].str.lower()

# %% [markdown]
# **Menghapus mention**

# %%
df['content'] = df['content'].str.replace('@\S+', ' ', case=False)

# %% [markdown]
# **Menghapus Hashtag**

# %%
df['content'] = df['content'].str.replace('#\S+', ' ', case=False)

# %% [markdown]
# **menghapus next karakter**

# %%
df['content'] = df['content'].str.replace("\'\w+", ' ', case=False)

# %% [markdown]
# **Menghapus tanda baca**

# %%
df['content'] = df['content'].str.replace("[^\w\s]", ' ', case=False)

# %% [markdown]
# **Menghapus extra whitespace**

# %%
df['content'] = df['content'].str.replace("\s(2)", ' ', case=False)

# %% [markdown]
# **Tokenizing**

# %%
# impor word_tokenize dari modul nltk
from nltk.tokenize import word_tokenize

# %%
#df['content']=df.apply(lambda row: nltk.word_tokenize(row['content']), axis=1)
from nltk.tokenize import RegexpTokenizer
regexp = RegexpTokenizer('\w+')
df['content_token']=df['content'].apply(regexp.tokenize)
df.head(3)
# Out:
#                                                 content  score  Year  Month  \
# 9733  aplikasinya bagus, aku suka tapi ada kekuranga...      4  2021      1
# 8862  aplikasinya bagus. fiturnya lengkap dan bisa o...      5  2021      3
# 8629  semua udah bagus.. hanya saja sedikit saran.. ...      4  2021      5
#
#       Day  sentiment                                      content_token
# 9733   14          1  [aplikasinya, bagus, aku, suka, tapi, ada, kek...
# 8862   25          1  [aplikasinya, bagus, fiturnya, lengkap, dan, b...
# 8629   23          1  [semua, udah, bagus, hanya, saja, sedikit, sar...

# %% [markdown]
# # Filtering (Stopword Removal)
#
# **Filtering** adalah tahap mengambil kata-kata penting dari hasil token dengan menggunakan algoritma stoplist (membuang kata kurang penting) atau wordlist (menyimpan kata penting).
#
# **Stopword** adalah kata umum yang biasanya muncul dalam jumlah besar dan dianggap tidak memiliki makna. Contoh stopword dalam bahasa Indonesia adalah “yang”, “dan”, “di”, “dari”, dll. Makna di balik penggunaan stopword yaitu dengan menghapus kata-kata yang memiliki informasi rendah dari sebuah teks, kita dapat fokus pada kata-kata penting sebagai gantinya.
#
# Contoh penggunaan filtering dapat kita temukan pada konteks mesin pencarian. Jika permintaan pencarian anda adalah “apa itu pengertian manajemen?” tentunya anda ingin sistem pencarian fokus pada memunculkan dokumen dengan topik tentang “pengertian manajemen” di atas dokumen dengan topik “apa itu”. Hal ini dapat dilakukan dengan mencegah kata dari daftar stopword dianalisa.
#
# https://www.kirenz.com/post/2021-12-11-text-mining-and-sentiment-analysis-with-nltk-and-pandas-in-python/text-mining-and-sentiment-analysis-with-nltk-and-pandas-in-python/

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# Make a list of english stopwords
stopwords = nltk.corpus.stopwords.words("indonesian")
# Extend the list with your own custom stopwords
my_stopwords = ['gojek']
stopwords.extend(my_stopwords)

# %%
# Remove stopwords
df['content_token'] = df['content_token'].apply(lambda x: [item for item in x if item not in stopwords])
df.head(3)
# Out:
#                                                 content  score  Year  Month  \
# 9733  aplikasinya bagus, aku suka tapi ada kekuranga...      4  2021      1
# 8862  aplikasinya bagus. fiturnya lengkap dan bisa o...      5  2021      3
# 8629  semua udah bagus.. hanya saja sedikit saran.. ...      4  2021      5
#
#       Day  sentiment                                      content_token
# 9733   14          1  [aplikasinya, bagus, suka, kekurangan, aplikas...
# 8862   25          1  [aplikasinya, bagus, fiturnya, lengkap, overla...
# 8629   23          1  [udah, bagus, saran, coba, pengaturan, edit, v...

# %% [markdown]
# # Stemming sastrawi

# %% [markdown]
# Sastrawi Python adalah library python sederhana yang memungkinkan Anda untuk mereduksi kata-kata infleksi dalam Bahasa Indonesia (Bahasa Indonesia) ke bentuk dasarnya (stem). Ini adalah port Python dari proyek Sastrawi asli yang ditulis dalam PHP (kredit diberikan kepada penulis asli dan kontributor Sastrawi PHP). https://medium.com/@93Kryptonian/stemming-with-sastrawi-877cc40a37ad

# %% [markdown]
# Stemming adalah teknik pemrosesan bahasa alami yang menurunkan infleksi kata ke bentuk akarnya, sehingga membantu dalam pra-pemrosesan teks, kata, dan dokumen untuk normalisasi teks.
#
# Menurut Wikipedia, infleksi adalah proses di mana sebuah kata dimodifikasi untuk mengkomunikasikan banyak kategori tata bahasa, termasuk tegang, kasus, suara, aspek, orang, jumlah, jenis kelamin, dan suasana hati. Jadi, meskipun sebuah kata mungkin ada dalam beberapa bentuk infleksi, memiliki beberapa bentuk infleksi di dalam teks yang sama menambah redundansi pada proses NLP.
#
# Akibatnya, kami menggunakan stemming untuk mengurangi kata ke bentuk dasar atau stem, yang mungkin atau mungkin bukan kata yang sah dalam bahasa tersebut.
#
# Misalnya, batang dari ketiga kata ini, koneksi, terhubung, menghubungkan, adalah "menghubungkan". Di sisi lain, akar masalah, masalah, dan masalah adalah "masalah", yang bukan kata yang dikenal.

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
df['stemmed'] = df['content_token'].apply(lambda x: [stemmer.stem(y) for y in x]) # Stem every word.

# %%
df.head(5)
# Out:
#                                                 content  score  Year  Month  \
# 9733  aplikasinya bagus, aku suka tapi ada kekuranga...      4  2021      1
# 8862  aplikasinya bagus. fiturnya lengkap dan bisa o...      5  2021      3
# 8629  semua udah bagus.. hanya saja sedikit saran.. ...      4  2021      5
# 8029  aplikasi sudah bagus secara keseluruhan. cuma ...      4  2021      9
# 7891  mau ngasih tau aja,kenapa ya apk capcut kalo b...      3  2021     10
#
#       Day  sentiment                                      content_token  \
# 9733   14          1  [aplikasinya, bagus, suka, kekurangan, aplikas...
# 8862   25          1  [aplikasinya, bagus, fiturnya, lengkap, overla...
# 8629   23          1  [udah, bagus, saran, coba, pengaturan, edit, v...
# 8029    4          1  [aplikasi, bagus, timeline, tolong, disatukan,...
# 7891    8          0  [ngasih, tau, aja, ya, apk, capcut, kalo, nged...
#
#                                                 stemmed
# 9733  [aplikasi, bagus, suka, kurang, aplikasi, tolo...
# 8862  [aplikasi, bagus, fiturnya, lengkap, overlay, ...
# 8629  [udah, bagus, saran, coba, atur, edit, video, ...
# 8029  [aplikasi, bagus, timeline, tolong, satu, pisa...
# 7891  [ngasih, tau, aja, ya, apk, capcut, kalo, nged...

# %% [markdown]
# ## Hanya yang lebih dari 3 kata yang dipakai

# %%
df['text_string'] = df['stemmed'].apply(lambda x: ' '.join([item for item in x if len(item)>3]))

# %%
df.head(5)
# Out:
#                                                 content  score  Year  Month  \
# 9733  aplikasinya bagus, aku suka tapi ada kekuranga...      4  2021      1
# 8862  aplikasinya bagus. fiturnya lengkap dan bisa o...      5  2021      3
# 8629  semua udah bagus.. hanya saja sedikit saran.. ...      4  2021      5
# 8029  aplikasi sudah bagus secara keseluruhan. cuma ...      4  2021      9
# 7891  mau ngasih tau aja,kenapa ya apk capcut kalo b...      3  2021     10
#
#       Day  sentiment                                      content_token  \
# 9733   14          1  [aplikasinya, bagus, suka, kekurangan, aplikas...
# 8862   25          1  [aplikasinya, bagus, fiturnya, lengkap, overla...
# 8629   23          1  [udah, bagus, saran, coba, pengaturan, edit, v...
# 8029    4          1  [aplikasi, bagus, timeline, tolong, disatukan,...
# 7891    8          0  [ngasih, tau, aja, ya, apk, capcut, kalo, nged...
#
#                                                 stemmed  \
# 9733  [aplikasi, bagus, suka, kurang, aplikasi, tolo...
# 8862  [aplikasi, bagus, fiturnya, lengkap, overlay, ...
# 8629  [udah, bagus, saran, coba, atur, edit, video, ...
# 8029  [aplikasi, bagus, timeline, tolong, satu, pisa...
# 7891  [ngasih, tau, aja, ya, apk, capcut, kalo, nged...
#
#                                             text_string
# 9733  aplikasi bagus suka kurang aplikasi tolong opt...
# 8862  aplikasi bagus fiturnya lengkap overlay video ...
# 8629  udah bagus saran coba atur edit video atur bis...
# 8029  aplikasi bagus timeline tolong satu pisah over...
# 7891  ngasih capcut kalo ngedit video durasi macet r...

# %%
df.to_csv('/content/drive/MyDrive/DATA MESIN LEARNING/ANALISIS APLIKASI CUPCUT/scrapping_data_capcut.csv') #write dataframe into csv file
#df = pd.read_csv('/content/scrapping_data_capcut.csv',index_col=0) #reads csv file

# %%
df.head()
# Out:
#                                                 content  score  Year  Month  \
# 9733  aplikasinya bagus, aku suka tapi ada kekuranga...      4  2021      1
# 8862  aplikasinya bagus. fiturnya lengkap dan bisa o...      5  2021      3
# 8629  semua udah bagus.. hanya saja sedikit saran.. ...      4  2021      5
# 8029  aplikasi sudah bagus secara keseluruhan. cuma ...      4  2021      9
# 7891  mau ngasih tau aja,kenapa ya apk capcut kalo b...      3  2021     10
#
#       Day  sentiment                                      content_token  \
# 9733   14          1  [aplikasinya, bagus, suka, kekurangan, aplikas...
# 8862   25          1  [aplikasinya, bagus, fiturnya, lengkap, overla...
# 8629   23          1  [udah, bagus, saran, coba, pengaturan, edit, v...
# 8029    4          1  [aplikasi, bagus, timeline, tolong, disatukan,...
# 7891    8          0  [ngasih, tau, aja, ya, apk, capcut, kalo, nged...
#
#                                                 stemmed  \
# 9733  [aplikasi, bagus, suka, kurang, aplikasi, tolo...
# 8862  [aplikasi, bagus, fiturnya, lengkap, overlay, ...
# 8629  [udah, bagus, saran, coba, atur, edit, video, ...
# 8029  [aplikasi, bagus, timeline, tolong, satu, pisa...
# 7891  [ngasih, tau, aja, ya, apk, capcut, kalo, nged...
#
#                                             text_string
# 9733  aplikasi bagus suka kurang aplikasi tolong opt...
# 8862  aplikasi bagus fiturnya lengkap overlay video ...
# 8629  udah bagus saran coba atur edit video atur bis...
# 8029  aplikasi bagus timeline tolong satu pisah over...
# 7891  ngasih capcut kalo ngedit video durasi macet r...

# %%
df.groupby(['Month','Day'])
print(df.groupby(['Month','Day']).groups)
# Out:
# {(1, 1): [8827, 8550, 9141, 8774, 8104, 9742, 8886], (1, 2): [9372, 8086, 6584, 8162, 9157, 8513, 7244, 9160, 8159, 8854, 6853, 9055], (1, 3): [8105, 9958, 7214, 7160, 6924, 6795, 9241, 2646, 2687, 6725, 6976], (1, 4): [6563, 7127, 9284, 8754, 3249, 4485, 9339, 2680, 2598, 9328, 9927, 2674, 6557, 6665, 8536, 6824, 6809, 9438, 9805, 9782, 6756, 2775, 4500, 6948, 8186, 9461, 6941, 8091, 4337, 9896, 9148, 7114, 6778, 8085, 2565, 4388, 9315], (1, 5): [4278, 8740, 8178, 2104, 5097, 6718, 6769, 7087, 8298, 4135, 9863, 8118, 7711, 8829, 7254, 6660, 9289, 8160, 8324, 4456, 8944, 9201, 4670, 6939, 2094, 6947], (1, 6): [7292, 6848, 5070, 6577, 7022, 7282, 3293, 6881, 6733, 2131, 7176, 9331, 8131, 6984, 6679, 6729, 7280, 3344, 7023, 6983, 9444, 4242, 5071, 7121, 6588, 2064, 9278, 7750, 8626, 9921], (1, 7): [6783, 7635, 7243, 9614, 7225, 7150, 8223, 3487, 7208, 8128, 8129, 8676, 9098, 2289, 7120, 8469, 8512, 6884, 2644, 6652, 7289, 9708, 6524, 9320], (1, 8): [2451, 2792, 8560, 9595, 6589, 7009, 2931, 8190, 9244, 7103, 7084, 7164, 4492, 8860, 3346, 8959, 7144, 2866, 9301, 9484, 7252, 2660, 4253], (1, 9): [8696, 6748, 6987, 6760, 8940, 9123, 8025, 7047, 8081, 4386, 6927, 4329, 9889, 9483, 4246, 9998, 7188], (1, 10): [9431, 8040, 9434, 3043, 9942, 8511, 9930, 2877, 9774, 7267, 8275, 8196, 2154, 9838, 7101, 7291, 6863, 9410, 7279, 2128, 6770, 9374], (1, 11): [8168, 8179, 6626, 6643, 2705, 6578, 2728, 2603, 8895, 9333, 6815, 7236, 2522, 4505, 6656, 8198, 6604, 2608, 7751, 2084, 8887, 6568, 7129, 4309, 9429, 6674, 2475, 2589], (1, 12): [9219, 8757, 9204, 7303, 7285, 4223, 7088, 9906, 8045, 9151, 9817, 6785, 4343, 4209, 8651, 8221, 4377, 2832, 9462, 8077, 2640, 7932, 7272, 6753], (1, 13): [8095, 4487, 7146, 7402, 9021, 9472, 6956, 7546, 6835, 7063, 4201, 4288, 7603, 8143, 7866, 9066, 4208, 2133, 9941, 7258, 8147, 9394], (1, 14): [9733, 6728, 9273, 6847, 9435, 4235, 6661, 4341, 9940, 4199, 9971, 6872, 6858, 9772, 8681, 2622, 7218, 8263, 7102, 4497, 9003, 2060, 2839], (1, 15): [9252, 6731, 9365, 9181, 6583, 9969, 2658, 7095, 2130, 2540, 8116, 6856, 9325, 7003, 7113, 2137, 4321, 9463], (1, 16): [4338, 4301, 9428, 7199, 7683, 7037, 8202, 6704, 9925, 9378, 3453, 6737, 9890, 7281, 4366, 9283, 9403, 2637, 2648, 6746, 8412, 7145, 7108], (1, 17): [6950, 8455, 2077, 3443, 7284, 2513, 4037, 8580, 9455, 2626, 8466, 9387, 6864, 8809, 7671, 6736, 2529, 9705, 2875, 6852, 4435, 4380, 7054], (1, 18): [7057, 4298, 9552, 8721, 4457, 6671, 2474, 9245, 7161, 7007, 4221, 7712, 8941, 9577, 6567, 6974, 3450, 7523, 9481, 6879, 2533, 2524, 6922, 7255, 4222, 7290, 2701, 2410, 9295], (1, 19): [7125, 9165, 6842, 7136, 6740, 9580, 4116, 7052, 9404, 4385, 7215, 9318, 4214, 9350, 6962, 4215, 2773, 7545, 3432, 4357, 6784, 8133, 7678, 6765, 6609, 6619, 4423, 2116, 2140, 7613, 9420], (1, 20): [8562, 8094, 9788, 8112, 9794, 7941, 9677, 9258, 7174, 4422, 2098, 6636, 7251, 6714, 7038, 2553, 7019, 2460, 4105, 8134, 6541, 3342, 9033, 7173, 2156, 3468, 6649, 2455, 6838, 9919, 6680, 2463], (1, 21): [4499, 7892, 8073, 8579, 8921, 7265, 9298, 8123, 6869, 7050, 9937, 6989, 7154, 9929, 8415, 2652, 2814], (1, 22): [9936, 4483, 2110, 7126, 7241, 8947, 3176, 6607, 7030, 9075, 4303, 9504, 7213, 9427, 9974, 2567, 8793, 6855, 7264, 8645, 8540, 8822, 6766, 7837, 2741, 6694], (1, 23): [7298, 6846, 6642, 8654, 9399, 7557, 8614, 6946, 7067, 2091, 6832, 2548, 8175, 6931, 4681, 4493, 9223, 6707, 7106, 2453, 6839, 7131, 7042, 7053], (1, 24): [9362, 9127, 9864, 6713, 2121, 8164, 6763, 7179, 8305, 8148, 6635, 9317, 6819, 9810, 9287, 6887, 7140, 9426, 6994, 2965, 6762, 3341, 2108, 9305, 6926, 7766], (1, 25): [3480, 7110, 8403, 9282, 6759, 7097, 2071, 2545, 6859, 3474, 3100, 7156, 9044, 4518, 7297, 9947, 7242, 8092, 7201, 6932, 9528], (1, 26): [4360, 4424, 7112, 7224, 7227, 7045, 9960, 7238, 8338, 2697, 4420, 4316, 3280, 7720, 7936, 9340, 8183, 4107, 2868, 8714, 8608, 2876, 9347, 6657, 5075, 8103, 7203, 9875, 9379, 6548, 4217, 2632, 6966, 2152], (1, 27): [4356, 6585, 9836, 9408, 9855, 7324, 6613, 7248, 7155 ...

# %% [markdown]
# # WORDCLOUD

# %% [markdown]
# wordcloud digunakan untuk memunculkan citraan visual dari sebuah teks tertulis kemudian dapat dijadikan sebagai sebuah alat bantu dalam melakukan analisis teks.
# kata-kata yang ada digambarkan kedalam suatu visualisasi dimana besar kecilnya huruf bergantung pada frekuensi munculnya kata tersebut didalam teks.
# singkatnya adalah kata terbesar adalah kata yang paling sering muncul dalam suatu data.

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %% [markdown]
# # wordcloud sentimen positif

# %%
df_p=df[df['sentiment']==1]

# %%
all_words_lem = ' '.join([word for word in df_p['text_string']])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(all_words_lem)

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %% [markdown]
# # wordcloud sentimen negatif

# %%
df_neg=df[df['sentiment']==-1]
all_words_lemneg = ' '.join([word for word in df_neg['text_string']])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(all_words_lemneg)

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %% [markdown]
# # wordcloud sentimen netral

# %%
df_net=df[df['sentiment']==0]
all_words_lemnet = ' '.join([word for word in df_net['text_string']])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(all_words_lemnet)

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %%
df['text_string']
# Out:
# 9733    aplikasi bagus suka kurang aplikasi tolong opt...
# 8862    aplikasi bagus fiturnya lengkap overlay video ...
# 8629    udah bagus saran coba atur edit video atur bis...
# 8029    aplikasi bagus timeline tolong satu pisah over...
# 7891    ngasih capcut kalo ngedit video durasi macet r...
#                               ...
# 2292    halah taik fitur premium kenal premium ngedit ...
# 2914         fitur fitur prabayar prabayar musik prabayar
# 5586                      aplikasi kont guna fitur capcut
# 2909              capcut internet jaring enak bikin kesel
# 7520    bagus bagus edit kalo bikin bayar susah kalo e...
# Name: text_string, Length: 10000, dtype: object

# %%
# Basic Operation
import pandas as pd
import numpy as np

# Text Preprocessing & Cleaning
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import re
from wordcloud import WordCloud,STOPWORDS
from nltk import SnowballStemmer


from sklearn.model_selection import train_test_split # Split Data
from imblearn.over_sampling import SMOTE # Handling Imbalanced

# Model Building
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from sklearn.svm import SVC


from sklearn.metrics import classification_report , confusion_matrix , accuracy_score # Performance Metrics


# Data Visualization
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
import warnings


warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
X = df['text_string']
y = df['sentiment']

# %% [markdown]
# https://www.kaggle.com/code/hummetbelli/twitter-us-airline-sentiment-nlp-95-acc

# %% [markdown]
# # Penerapan TF-IDF
# Term frequency-inverse document frequency adalah text vectorizer yang mengubah teks menjadi vektor yang dapat digunakan. Ini menggabungkan 2 konsep, Term Frequency (TF) dan Document Frequency (DF).
#
# Frekuensi istilah adalah jumlah kemunculan istilah tertentu dalam dokumen. Frekuensi istilah menunjukkan seberapa penting istilah tertentu dalam sebuah dokumen. Frekuensi istilah mewakili setiap teks dari data sebagai matriks yang barisnya adalah jumlah dokumen dan kolomnya adalah jumlah istilah yang berbeda di seluruh dokumen.
#
# Frekuensi dokumen adalah jumlah dokumen yang mengandung istilah tertentu. Frekuensi dokumen menunjukkan seberapa umum istilah tersebut.
#
# Inverse document frequency (IDF) adalah bobot suatu term, hal ini bertujuan untuk mengurangi bobot suatu term jika kemunculan term tersebar di seluruh dokumen. IDF dapat dihitung sebagai berikut:
# ![rumus idf.webp](data:image/webp;base64,...)
#
#
# Dimana idfᵢ adalah skor IDF untuk term i, dfᵢ adalah jumlah dokumen yang mengandung term i, dan n adalah jumlah total dokumen. Semakin tinggi DF suatu term, semakin rendah IDF untuk term tersebut. Ketika jumlah DF sama dengan n yang berarti istilah tersebut muncul di semua dokumen, IDF akan menjadi nol, karena log(1) adalah nol, jika ragu masukkan saja istilah ini ke dalam daftar stopword karena tidak menyediakan banyak informasi.
#
# Skor TF-IDF seperti namanya hanyalah perkalian dari matriks frekuensi term dengan IDF-nya, dapat dihitung sebagai berikut:
#
# ![idf.png](data:image/png;base64,...)
#
# Dimana wᵢⱼ adalah skor TF-IDF untuk term i pada dokumen j, tfᵢⱼ adalah frekuensi term untuk term i pada dokumen j, dan idfᵢ adalah skor IDF untuk term i.

# %%
tfid = TfidfVectorizer()
X_final =  tfid.fit_transform(X)

# %% [markdown]
# # HANDLING IMBALANCE
# Dalam Machine Learning dan Data Science sering kita jumpai istilah yang disebut Distribusi Data Tidak Seimbang, umumnya terjadi ketika pengamatan di salah satu kelas jauh lebih tinggi atau lebih rendah dari kelas lainnya. Karena algoritma Machine Learning cenderung meningkatkan akurasi dengan mengurangi kesalahan, mereka tidak mempertimbangkan distribusi kelas.
#
# Masalah ini lazim dalam contoh-contoh seperti Deteksi Penipuan, Deteksi Anomali, Pengenalan wajah, dll.
#
# Teknik ML standar seperti Decision Tree dan Logistic Regression memiliki bias terhadap kelas mayoritas, dan cenderung mengabaikan kelas minoritas. Mereka cenderung hanya memprediksi kelas mayoritas, oleh karena itu, memiliki kesalahan klasifikasi yang besar dari kelas minoritas dibandingkan dengan kelas mayoritas.
#
# Dengan kata yang lebih teknis, jika kita memiliki distribusi data yang tidak seimbang dalam kumpulan data kita, maka model kita menjadi lebih rentan terhadap kasus ketika kelas minoritas memiliki ingatan yang dapat diabaikan atau sangat rendah.

# %%
# Handling imbalanced using SMOTE
smote = SMOTE()
x_sm,y_sm = smote.fit_resample(X_final,y)

# %% [markdown]
# # Split Data into train & test data train 90%, data tes 10%

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.1,random_state=3)

# %% [markdown]
# # MODELLING

# %% [markdown]
# ## Random Forest

# %%
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)

# %%
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.9038461538461539

# %% [markdown]
# # Support vector machine

# %%
svm = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
svm_prediction =  svm.predict(X_test)

# %%
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8669028340080972

# %% [markdown]
# # Naive Bayes

# %%
nb = MultinomialNB()
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
nb_prediction =  nb.predict(X_test)

# %%
accuracy_score(nb_prediction,y_test)
# Out:
# 0.7105263157894737

# %% [markdown]
# # Split Data into train & test data train 80%, data tes 20%

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.2,random_state=3)

# %% [markdown]
# ## Random Forest

# %%
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)

# %%
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8987854251012146

# %% [markdown]
# # Support vector machine

# %%
svm = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
svm_prediction =  svm.predict(X_test)

# %%
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8415991902834008

# %% [markdown]
# # Naive Bayes

# %%
nb = MultinomialNB()
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
nb_prediction =  nb.predict(X_test)

# %%
accuracy_score(nb_prediction,y_test)
# Out:
# 0.7148279352226721

# %% [markdown]
# # Split Data into train & test data train 70%, data tes 30%

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.3,random_state=3)

# %% [markdown]
# ## Random Forest

# %%
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)

# %%
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8566352815775449

# %% [markdown]
# # Support vector machine

# %%
svm = SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
svm_prediction =  svm.predict(X_test)

# %%
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8415991902834008

# %% [markdown]
# # Naive Bayes

# %%
nb = MultinomialNB()
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
nb_prediction =  nb.predict(X_test)

# %%
accuracy_score(nb_prediction,y_test)
# Out:
# 0.7096828609986505

# %% [markdown]
# # Split Data into train & test data train 60%, data tes 40%

# %%
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.4,random_state=3)

# %%
# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.865005060728745

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8415991902834008

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.7033147773279352

# %%
#split 50,50
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.5,random_state=3)

# %%
# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8504909403785809

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.833991294665452

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.694807166717279

# %%
#split 40,60
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.6,random_state=3)

# %%
# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.8238717840573597

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.8134964150147617

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.6905103331927457

# %%
#split 40,60
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.7,random_state=3)

# %%
# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.7954594750921842

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.7986407345817367

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.6705950401272504

# %%
#split 20, 80
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.8,random_state=3)

# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.7511861833364964

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.7735813247295502

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.6647055102169924

# %%
#split 10, 90
X_train , X_test , y_train , y_test = train_test_split(x_sm , y_sm , test_size=0.9,random_state=3)

# Random Forest
random_forest_classifier = RandomForestClassifier()
random_forest_classifier.fit(X_train,y_train)
random_forest_classifier_prediction =  random_forest_classifier.predict(X_test)
accuracy_score(random_forest_classifier_prediction,y_test)
# Out:
# 0.6844739357813642

# %%
# Support vector machine
svm = SVC()
svm.fit(X_train,y_train)
svm_prediction =  svm.predict(X_test)
accuracy_score(svm_prediction,y_test)
# Out:
# 0.7146150818197154

# %%
# Naive Bayes

nb = MultinomialNB()
nb.fit(X_train,y_train)
nb_prediction =  nb.predict(X_test)
accuracy_score(nb_prediction,y_test)
# Out:
# 0.6176685598605409

# %%
# initialize list of lists
data_akurasi = [[90,10,88.28,87.41,71.99], [80,20,87.37,86.78,72.46],[70,30,86.57,86.78,72.07],[60,40,85.20,85.65,71.60],[50,50,84.06,84.75,70.86],[40,60,81.76,82.92,69.35],[30,70,79.49,81.94,68.73],[20,80,66.59,79.21,66.59],[10,90,69.96,76.60,63.89]]

# Create the pandas DataFrame
df_akurasi = pd.DataFrame(data_akurasi, columns=['data_train', 'data_tes', 'random_fores', 'SVM', 'naive_bayes'])

# print dataframe.
df_akurasi
# Out:
#    data_train  data_tes  random_fores    SVM  naive_bayes
# 0          90        10         88.28  87.41        71.99
# 1          80        20         87.37  86.78        72.46
# 2          70        30         86.57  86.78        72.07
# 3          60        40         85.20  85.65        71.60
# 4          50        50         84.06  84.75        70.86
# 5          40        60         81.76  82.92        69.35
# 6          30        70         79.49  81.94        68.73
# 7          20        80         66.59  79.21        66.59
# 8          10        90         69.96  76.60        63.89

# %%
# Importing packages
import matplotlib.pyplot as plt

# %%
plt.plot(df_akurasi['data_train'], df_akurasi['random_fores'], 'g', label='Random Forest')
plt.plot(df_akurasi['data_train'], df_akurasi['SVM'], 'r', label='SVM')
plt.plot(df_akurasi['data_train'], df_akurasi['naive_bayes'], 'y', label='Naive Bayes')
plt.xlabel('Jumlah Data Train dalam %', fontsize=18)
plt.ylabel('Nilai Akurasi dalam %', fontsize=16)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#sorting berdasarkan data train ascending
df_akurasi = df_akurasi.sort_values(by='data_train', ascending=True)
# set width of bar
barWidth = 0.3
fig = plt.subplots(figsize =(12, 8))

# set height of bar
#IT = [12, 30, 1, 8, 22]
#ECE = [28, 6, 16, 5, 10]
#CSE = [29, 3, 24, 25, 17]

# Set position of bar on X axis
br1 = np.arange(len(df_akurasi['random_fores']))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot
plt.bar(br1, df_akurasi['random_fores'], color ='orange', width = barWidth,
		edgecolor ='grey', label ='Random Forest')
plt.bar(br2, df_akurasi['SVM'], color ='b', width = barWidth,
		edgecolor ='grey', label ='svm')
plt.bar(br3, df_akurasi['naive_bayes'], color ='magenta', width = barWidth,
		edgecolor ='grey', label ='Naive Bayes')

plt.ylim(40, 90)
# Adding Xticks
plt.xlabel('Data Train dalam %', fontweight ='bold', fontsize = 15)
plt.ylabel('Akurasi dalam %', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(df_akurasi['random_fores']))],
		df_akurasi['data_train'])

plt.legend()
plt.show()

# %% [markdown]
# VISUALIZE BEST MODEL PERFORMENCE

# %%
cr = classification_report(y_test, random_forest_classifier_prediction)

# %%
print("Classification Report:\n----------------------\n", cr)

cm = confusion_matrix(y_test,random_forest_classifier_prediction)


# plot confusion matrix
plt.figure(figsize=(10,6))
sentiment_classes = ['Negative', 'Neutral', 'Positive']
sns.heatmap(cm, cmap=plt.cm.Blues, annot=True, fmt='d',
            xticklabels=sentiment_classes,
            yticklabels=sentiment_classes)
plt.title('Confusion matrix-TFIDF', fontsize=16)
plt.xlabel('Actual label', fontsize=12)
plt.ylabel('Predicted label', fontsize=12)
plt.show()
# Out:
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#           -1       0.72      0.71      0.71      5947
#            0       0.67      0.59      0.63      5918
#            1       0.66      0.75      0.70      5918
#
#     accuracy                           0.68     17783
#    macro avg       0.69      0.68      0.68     17783
# weighted avg       0.69      0.68      0.68     17783

# %% [markdown]
# # Frequency distributions

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

words = nltk.word_tokenize(all_words_lem)
fd = FreqDist(words)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-137-2890494411.py in <cell line: 0>()
#       2 from nltk.probability import FreqDist
#       3
# ----> 4 words = nltk.word_tokenize(all_words_lem)
#       5 fd = FreqDist(words)
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#     121
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/__init__.py in _get_punkt_tokenizer(language)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#     106
#     107
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/punkt.py in __init__(self, lang)
#    1742     def __init__(self, lang="english"):
#    1743         PunktSentenceTokenizer.__init__(self)
# -> 1744         self.load_lang(lang)
#    1745
#    1746     def load_lang(self, lang="english"):
#
# /usr/local/lib/python3.11/dist-packages/nltk/tokenize/punkt.py in load_lang(self, lang)
#    1747         from nltk.data import find
#    1748
# -> 1749         lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750         self._params = load_punkt_params(lang_dir)
#    1751         self._lang = lang
#
# /usr/local/lib/python3.11/dist-packages/nltk/data.py in find(resource_name, paths)
#     577     sep = "*" * 70
#     578     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579     raise LookupError(resource_not_found)
#     580
#     581
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# # Most common words

# %%
fd.most_common(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-138-222390469.py in <cell line: 0>()
# ----> 1 fd.most_common(3)
#
# NameError: name 'fd' is not defined

# %%
fd.tabulate(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-139-3632489950.py in <cell line: 0>()
# ----> 1 fd.tabulate(3)
#
# NameError: name 'fd' is not defined

# %% [markdown]
# # Plot common words

# %%
# Obtain top 10 words
top_10 = fd.most_common(10)

# Create pandas series to make plotting easier
fdist = pd.Series(dict(top_10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-140-1498107363.py in <cell line: 0>()
#       1 # Obtain top 10 words
# ----> 2 top_10 = fd.most_common(10)
#       3
#       4 # Create pandas series to make plotting easier
#       5 fdist = pd.Series(dict(top_10))
#
# NameError: name 'fd' is not defined

# %%
import seaborn as sns
sns.set_theme(style="ticks")

sns.barplot(y=fdist.index, x=fdist.values, color='blue');

# %%
import plotly.express as px

fig = px.bar(y=fdist.index, x=fdist.values)

# sort values
fig.update_layout(barmode='stack', yaxis={'categoryorder':'total ascending'})

# show plot
fig.show()
